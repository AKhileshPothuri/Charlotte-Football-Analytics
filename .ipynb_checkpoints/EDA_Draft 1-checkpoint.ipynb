# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
current_directory = os.getcwd()
files = os.listdir(current_directory)
for file in files:
    print(file)
# Out:
# Report3_apothuri.docx
# Report2_apothuri.pdf
# Report3_apothuri.pdf
# README.md
# Report1_apothuri.docx
# Report1_apothuri.pdf
# Internship_Project_Proposal_Akhilesh.pdf
# Report2_apothuri.docx
# .ipynb_checkpoints
# .git
# EDA_Draft 1.ipynb
# Internship_Project_Proposal_Akhilesh.docx
# FirstTrimesterCCData.csv

# %%
raw_df = pd.read_csv("FirstTrimesterCCData.csv")

# %%
raw_df.head()
# Out:
#       #                                       Name  Play Number QB Comment  \
# 0  71.0  01 NCCR OFF vs. MDUN (09/09/23), Play 001          1.0        NaN
# 1  72.0  01 NCCR OFF vs. MDUN (09/09/23), Play 002          2.0        NaN
# 2  73.0  01 NCCR OFF vs. MDUN (09/09/23), Play 003          3.0        NaN
# 3  74.0  01 NCCR OFF vs. MDUN (09/09/23), Play 004          4.0        NaN
# 4  75.0  01 NCCR OFF vs. MDUN (09/09/23), Play 005          5.0        NaN
#
#    Series  Field Position  Down  Distance  Gain  OFF Group  ...  \
# 0     1.0           -25.0   0.0      10.0   4.0        NaN  ...
# 1     1.0           -29.0   2.0       6.0   6.0        NaN  ...
# 2     1.0           -35.0   1.0      10.0   9.0        NaN  ...
# 3     1.0           -44.0   2.0       1.0   8.0        NaN  ...
# 4     1.0            48.0   1.0      10.0  48.0        NaN  ...
#
#   pff_QBSCRAMBLE pff_RBALIGNMENT           pff_RBDEPTH pff_RBDIRECTION  \
# 0            NaN            HB-L             HB-L (-5)               R
# 1            NaN              HB               HB (-7)               L
# 2            NaN      HB-R; FB-L  HB-R (-5); FB-L (-4)               L
# 3            NaN            HB-R             HB-R (-6)               R
# 4            NaN            HB-R             HB-R (-5)             NaN
#
#                   pff_RBSINBACKFIELD pff_RUNCONCEPTPRIMARY  \
# 0                  1; NCCR 13 (HB-L)               COUNTER
# 1                    1; NCCR 01 (HB)               COUNTER
# 2  2; NCCR 00 (HB-R); NCCR 35 (FB-L)                 POWER
# 3                  1; NCCR 00 (HB-R)                   MAN
# 4                  1; NCCR 00 (HB-R)                   NaN
#
#   pff_RUNCONCEPTSECONDARY pff_SACK pff_TEALIGNMENT pff_PLAYCLOCK
# 0                 QB RUNS      NaN               L          11.0
# 1              CROSS LEAD      NaN         L;R;R;R           4.0
# 2    INVERTED;READ OPTION      NaN               L           1.0
# 3            LEAD;QB RUNS      NaN             R;R           7.0
# 4                     NaN      NaN               L           1.0
#
# [5 rows x 89 columns]

# %%
raw_df['QB Comment'].unique()
# Out:
# array([nan, '#35 BLOCK', '#86 HARD RUN', 'HELL YEAH', '#0 HARD RUN',
#        '#19 BLOCK', '#52 MA. LOAD = SLIDE RT. QB PRESSURE',
#        '#76 BAD SET = QB PRESSURE',
#        '#76 PENALTY. TAKES AWAY 3RD DOWN CONVERSION'], dtype=object)

# %%
raw_df.columns
# Out:
# Index(['#', 'Name', 'Play Number', 'QB Comment', 'Series', 'Field Position',
#        'Down', 'Distance', 'Gain', 'OFF Group', 'Personnel', 'The_Play',
#        'Backfield', 'FIB', 'Formation', 'Form Adj Y', 'Form Adj WR',
#        'Form Adj Bunch Stick', 'Empty', 'Motion', 'Motion 2', 'Motion 3',
#        'Protection', 'Play', 'Tempo', 'Run Concept', 'Pass Concept',
#        'Pass Concept 1', 'Pass Concept 2', 'Screen Concept', 'RPO1', 'ADDON 1',
#        'R/P', 'Pass Result', 'MOE', 'QB#', 'J#', 'EFF', 'gamedate',
#        'pff_GAMEDATE', 'pff_WEEK', 'pff_QUARTER', 'pff_DOWN', 'pff_CLOCK',
#        'pff_2MINUTE', 'pff_DRIVESTARTEVENT', 'pff_DRIVEENDEVENT',
#        'pff_DRIVESTARTFIELDPOSITION', 'pff_DRIVEENDFIELDPOSITION',
#        'pff_FIELDPOSITION', 'pff_DRIVEENDPLAYNUMBER', 'pff_DRIVE',
#        'pff_DRIVEPLAY', 'pff_GAINLOSS', 'pff_GAINLOSSNET', 'pff_DISTANCE',
#        'pff_FIRST_DOWN_GAINED', 'pff_RUNPASS', 'pff_RUNPASSOPTION',
#        'pff_PASSRESULT', 'pff_QB', 'pff_BALLCARRIER', 'pff_PENALTYYARDS',
#        'pff_SCORE', 'pff_SCOREDIFFERENTIAL', 'pff_OFFPERSONNELBASIC',
#        'pff_OFFPERSONNEL', 'pff_OFFFORMATIONGROUP', 'pff_TIMETOTHROW',
#        'pff_YARDSAFTERCATCH', 'pff_YARDSAFTERCONTACT', 'pff_DEFPERSONNEL',
#        'pff_HASH', 'pff_INTERCEPTION', 'pff_PASSDIRECTION',
#        'pff_PASSRECEIVERTARGET', 'Unnamed: 37', 'pff_PENALTY',
#        'pff_QBPRESSUREALLOWED', 'pff_QBSCRAMBLE', 'pff_RBALIGNMENT',
#        'pff_RBDEPTH', 'pff_RBDIRECTION', 'pff_RBSINBACKFIELD',
#        'pff_RUNCONCEPTPRIMARY', 'pff_RUNCONCEPTSECONDARY', 'pff_SACK',
#        'pff_TEALIGNMENT', 'pff_PLAYCLOCK'],
#       dtype='object')

# %%
display(raw_df)
# Out:
#          #                                       Name  Play Number QB Comment  \
# 0     71.0  01 NCCR OFF vs. MDUN (09/09/23), Play 001          1.0        NaN
# 1     72.0  01 NCCR OFF vs. MDUN (09/09/23), Play 002          2.0        NaN
# 2     73.0  01 NCCR OFF vs. MDUN (09/09/23), Play 003          3.0        NaN
# 3     74.0  01 NCCR OFF vs. MDUN (09/09/23), Play 004          4.0        NaN
# 4     75.0  01 NCCR OFF vs. MDUN (09/09/23), Play 005          5.0        NaN
# ..     ...                                        ...          ...        ...
# 255  256.0  04 NCCR OFF vs. FLUN (09/23/23), Play 056         56.0        NaN
# 256  257.0  04 NCCR OFF vs. FLUN (09/23/23), Play 057         57.0        NaN
# 257  258.0  04 NCCR OFF vs. FLUN (09/23/23), Play 058         58.0        NaN
# 258  259.0  04 NCCR OFF vs. FLUN (09/23/23), Play 059         59.0        NaN
# 259    NaN                                        NaN          NaN        NaN
#
#      Series  Field Position  Down  Distance  Gain  OFF Group  ...  \
# 0       1.0           -25.0   0.0      10.0   4.0        NaN  ...
# 1       1.0           -29.0   2.0       6.0   6.0        NaN  ...
# 2       1.0           -35.0   1.0      10.0   9.0        NaN  ...
# 3       1.0           -44.0   2.0       1.0   8.0        NaN  ...
# 4       1.0            48.0   1.0      10.0  48.0        NaN  ...
# ..      ...             ...   ...       ...   ...        ...  ...
# 255    11.0            35.0   1.0      10.0   0.0        NaN  ...
# 256    11.0            35.0   2.0      10.0   0.0        NaN  ...
# 257    11.0            35.0   3.0      10.0   0.0        NaN  ...
# 258    11.0            35.0   4.0      10.0   0.0        NaN  ...
# 259     NaN             NaN   NaN       NaN   NaN        NaN  ...
#
#     pff_QBSCRAMBLE pff_RBALIGNMENT           pff_RBDEPTH pff_RBDIRECTION  \
# 0              NaN            HB-L             HB-L (-5)               R
# 1              NaN              HB               HB (-7)               L
# 2              NaN      HB-R; FB-L  HB-R (-5); FB-L (-4)               L
# 3              NaN            HB-R             HB-R (-6)               R
# 4              NaN            HB-R             HB-R (-5)             NaN
# ..             ...             ...                   ...             ...
# 255            NaN            HB-L             HB-L (-6)               L
# 256            NaN            HB-R             HB-R (-5)               R
# 257            NaN            HB-R             HB-R (-5)               L
# 258            NaN            HB-L             HB-L (-5)               L
# 259            NaN             NaN                   NaN             NaN
#
#                     pff_RBSINBACKFIELD pff_RUNCONCEPTPRIMARY  \
# 0                    1; NCCR 13 (HB-L)               COUNTER
# 1                      1; NCCR 01 (HB)               COUNTER
# 2    2; NCCR 00 (HB-R); NCCR 35 (FB-L)                 POWER
# 3                    1; NCCR 00 (HB-R)                   MAN
# 4                    1; NCCR 00 (HB-R)                   NaN
# ..                                 ...                   ...
# 255                  1; NCCR 13 (HB-L)                   NaN
# 256                  1; NCCR 21 (HB-R)                   NaN
# 257                  1; NCCR 13 (HB-R)                 POWER
# 258                  1; NCCR 13 (HB-L)                   NaN
# 259                                NaN                   NaN
#
#     pff_RUNCONCEPTSECONDARY pff_SACK pff_TEALIGNMENT pff_PLAYCLOCK
# 0                   QB RUNS      NaN               L          11.0
# 1                CROSS LEAD      NaN         L;R;R;R           4.0
# 2      INVERTED;READ OPTION      NaN               L           1.0
# 3              LEAD;QB RUNS      NaN             R;R           7.0
# 4                       NaN      NaN               L           1.0
# ..                      ...      ...             ...           ...
# 255                     NaN      NaN               R          24.0
# 256                     NaN      NaN               L           4.0
# 257                     NaN      NaN               R           4.0
# 258                     NaN      NaN               R           4.0
# 259                     NaN      NaN             NaN           NaN
#
# [260 rows x 89 columns]

# %%
raw_df.shape
# Out:
# (260, 89)

# %%
raw_df.isna().sum()
# Out:
# #                            1
# Name                         1
# Play Number                  1
# QB Comment                 250
# Series                       5
#                           ...
# pff_RUNCONCEPTPRIMARY      121
# pff_RUNCONCEPTSECONDARY    179
# pff_SACK                   248
# pff_TEALIGNMENT             76
# pff_PLAYCLOCK               49
# Length: 89, dtype: int64

# %%
raw_df.describe()
# Out:
#                 #  Play Number      Series  Field Position       Down  \
# count  259.000000   259.000000  255.000000      259.000000  259.00000
# mean   130.000000    33.088803    6.478431       -9.548263    1.80695
# std     74.911058    19.091676    3.159557       32.224031    1.11777
# min      1.000000     1.000000    1.000000      -49.000000    0.00000
# 25%     65.500000    17.000000    4.000000      -38.000000    1.00000
# 50%    130.000000    33.000000    6.000000      -25.000000    2.00000
# 75%    194.500000    49.000000    9.000000       19.500000    3.00000
# max    259.000000    70.000000   12.000000       50.000000    5.00000
#
#          Distance        Gain  OFF Group         QB#          J#  ...  \
# count  259.000000  237.000000        0.0  257.000000  245.000000  ...
# mean     8.826255    5.375527        NaN    5.961089   14.853061  ...
# std      4.236781    9.764077        NaN    3.149660   20.362766  ...
# min      1.000000  -13.000000        NaN    4.000000    0.000000  ...
# 25%      6.500000    0.000000        NaN    4.000000    4.000000  ...
# 50%     10.000000    3.000000        NaN    4.000000   11.000000  ...
# 75%     10.000000    8.000000        NaN   11.000000   18.000000  ...
# max     23.000000   58.000000        NaN   11.000000   86.000000  ...
#
#        pff_RUNPASSOPTION  pff_PENALTYYARDS   pff_SCORE  pff_SCOREDIFFERENTIAL  \
# count         216.000000          8.000000  216.000000             216.000000
# mean            0.129630         -2.250000   12.129630              -3.370370
# std             0.336676          8.224528   10.322333              12.598702
# min             0.000000        -10.000000    0.000000             -24.000000
# 25%             0.000000         -8.500000    0.000000             -13.250000
# 50%             0.000000         -2.500000   13.500000              -7.000000
# 75%             0.000000          0.000000   19.000000              11.000000
# max             1.000000         15.000000   38.000000              21.000000
#
#        pff_OFFPERSONNELBASIC  pff_TIMETOTHROW  pff_YARDSAFTERCATCH  \
# count             216.000000       110.000000            59.000000
# mean               11.689815         2.906364             5.762712
# std                 0.618391         1.214989             6.744957
# min                11.000000         0.600000             0.000000
# 25%                11.000000         2.100000             1.000000
# 50%                12.000000         2.600000             4.000000
# 75%                12.000000         3.575000             7.500000
# max                14.000000         7.400000            38.000000
#
#        pff_YARDSAFTERCONTACT  Unnamed: 37  pff_PLAYCLOCK
# count             173.000000          0.0     211.000000
# mean                2.421965          NaN      12.563981
# std                 4.434403          NaN       7.332863
# min                -1.000000          NaN       0.000000
# 25%                 0.000000          NaN       6.500000
# 50%                 2.000000          NaN      12.000000
# 75%                 3.000000          NaN      18.000000
# max                52.000000          NaN      34.000000
#
# [8 rows x 34 columns]

# %%
# Histogram of 'Gain'
plt.hist(raw_df['Gain'], bins=20)
plt.xlabel('Gain')
plt.ylabel('Frequency')
plt.title('Distribution of Gain')
plt.show()

# 3. Data Visualization
# Bar chart for 'Formation'
plt.figure(figsize=(10, 6))
sns.countplot(data=raw_df, x='Formation')
plt.xticks(rotation=45)
plt.title('Formation Distribution')
plt.show()

# Scatter plot to explore relationships
plt.scatter(raw_df['Distance'], raw_df['Gain'])
plt.xlabel('Distance')
plt.ylabel('Gain')
plt.title('Gain vs. Distance')
plt.show()

# 5. Correlation Analysis
correlation_matrix = raw_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(raw_df['Gain'], bins=20, kde=True)
plt.title("Distribution of Gain")
plt.xlabel("Gain")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.countplot(raw_df['Down'])
plt.title("Distribution of Down")
plt.xlabel("Down")
plt.ylabel("Count")
plt.show()
# Out:
# /Users/akhileshpothuri/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
raw_df[['Play','gamedate','Gain']]
# Out:
#                       Play   gamedate  Gain
# 0               AKRON EDGE   9/9/2023   4.0
# 1     S. CINCY EDGE Z-BOSS   9/9/2023   6.0
# 2    S. PITT COVER Z-CRACK   9/9/2023   9.0
# 3            BEETLE FOLLOW   9/9/2023   8.0
# 4           S. GOLFER SAIL   9/9/2023  48.0
# ..                     ...        ...   ...
# 255          JILL PIN BOOT  9/23/2023   0.0
# 256                 SPRINT  9/23/2023   0.0
# 257           S. CALI RUBY  9/23/2023   0.0
# 258    JILL H-DRIVE DANCER  9/23/2023   0.0
# 259                    NaN        NaN   NaN
#
# [260 rows x 3 columns]

# %%
raw_df.gamedate.unique()
# Out:
# array(['9/9/2023', '9/2/2023', '9/16/2023', '9/23/2023', nan],
#       dtype=object)

# %%
plt.figure(figsize=(12, 6))
sns.countplot(raw_df['Formation'])
plt.title("Distribution of Formations")
plt.xlabel("Formation")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# /Users/akhileshpothuri/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12, 6))
sns.countplot(raw_df['Pass Concept'])
plt.title("Distribution of Formations")
plt.xlabel("Formation")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# /Users/akhileshpothuri/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12, 6))
sns.countplot(raw_df['Run Concept'])
plt.title("Distribution of Formations")
plt.xlabel("Formation")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# /Users/akhileshpothuri/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
correlation_matrix = raw_df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Game Stats Analysis

# %% [markdown]
# What are the key statistics for each game?
# How did the team perform in terms of wins and losses?
# What was the average gain and yards after catch for each game?

# %%
raw_df['gamedate'] = pd.to_datetime(raw_df['gamedate'], errors='coerce')

# Game Statistics Analysis
game_stats = raw_df.groupby('gamedate').agg({
    'Gain': 'mean',
    'pff_YARDSAFTERCATCH': 'mean',
    'pff_SCOREDIFFERENTIAL': 'last'  # Assuming 'pff_SCOREDIFFERENTIAL' represents the game result.
}).reset_index()

# Plot the average gain and yards after catch for each game.
plt.figure(figsize=(10, 6))
sns.lineplot(data=game_stats, x='gamedate', y='Gain', label='Average Gain')
sns.lineplot(data=game_stats, x='gamedate', y='pff_YARDSAFTERCATCH', label='Average YAC')
plt.xlabel("Game Date")
plt.ylabel("Average Value")
plt.title("Game Statistics Analysis")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Down and Distance Analysis

# %% [markdown]
# How did the team perform on different downs and distances?
# What was the success rate on 3rd and short, 3rd and long, etc.?

# %%
# Down and Distance Analysis
down_distance_stats = raw_df.groupby(['Down', 'Distance']).agg({
    'Gain': 'mean',
}).reset_index()

# Plot the average gain for each down and distance combination.
plt.figure(figsize=(10, 6))
sns.heatmap(down_distance_stats.pivot('Down', 'Distance', 'Gain'), annot=True, cmap='coolwarm')
plt.title("Average Gain by Down and Distance")
plt.xlabel("Distance")
plt.ylabel("Down")
plt.show()

# %% [markdown]
# ### Formation Analysis

# %% [markdown]
# What formations are commonly used by the team?
# Are certain formations more successful than others in terms of gains?

# %%
# Formation Analysis
formation_counts = raw_df['Formation'].value_counts()
formation_avg_gain = raw_df.groupby('Formation')['Gain'].mean().sort_values()

# Plot the count and average gain for each formation.
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.barplot(x=formation_counts, y=formation_counts.index, orient='h')
plt.title("Formation Counts")

plt.subplot(1, 2, 2)
sns.barplot(x=formation_avg_gain, y=formation_avg_gain.index, orient='h')
plt.title("Average Gain by Formation")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pass vs Run Analysis

# %% [markdown]
# How often did the team pass vs. run the ball?
# What was the success rate for passing and running plays?

# %%
# Pass vs. Run Analysis
run_pass_counts = raw_df['pff_RUNPASS'].value_counts()
run_pass_avg_gain = raw_df.groupby('pff_RUNPASS')['Gain'].mean()

# Plot the count and average gain for pass vs. run plays.
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
sns.barplot(x=run_pass_counts, y=run_pass_counts.index, orient='h')
plt.title("Run vs. Pass Counts")

plt.subplot(1, 2, 2)
sns.barplot(x=run_pass_avg_gain, y=run_pass_avg_gain.index, orient='h')
plt.title("Average Gain for Run vs. Pass")
plt.tight_layout()
plt.show()
